# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from bs4 import BeautifulSoup as Soup
import pandas as pd
import time
import requests

# %%
"""Les infos à scraper :
-	Titre
-	Nom de la boite
-	Adresse(Ville)
-	Salaire
-	Descriptif du poste
-	Date de publication de l’annonce
"""

# %%
city_to_scrap = ['Paris', 'Lyon', 'Toulouse', 'Nantes', 'Bordeaux']
work_to_scrap = ['développeur', 'data scientist', 'data analyst', 'business intelligence']

# %%
df = pd.DataFrame(columns=["Titre","Entreprise","Ville","Salaire","Type de contrat", "Descriptif du poste", "Date de publication"])

# %%
#pour chaque élément dans la liste city 
#Pour chaque élément dans la liste work
#entrer city_to_scrap[élec] dans ville où
#enter work_to_scrap[élew] dans quoi

# %%
browser = webdriver.Chrome()
browser.get('https://www.indeed.fr/')
browser.maximize_window()

# %%
def starting(job, ville):
    #Choisir localisation(temps d'attente pour le click)
    entrer_job = browser.find_element_by_xpath('//*[@id="text-input-what"]')
    entrer_job.send_keys(job)
    time.sleep(1)
    #Ecrire ville
    entrer_city = browser.find_element_by_xpath('//*[@id="text-input-where"]')
    entrer_city.send_keys(ville)
    time.sleep(1)
    #Recherche 
    button_search = browser.find_element_by_class_name("icl-Button")
    button_search.click()
    time.sleep(2)
starting('dev','Paris')

# %%
"""for i in range:
    starting()"""
for chaque in browser.find_elements_by_class_name('result'):
    #Scraping le titre sinon rien 
        #Cliquer sur l'annonce
    chaque.find_element_by_class_name('jobtitle').click()
    time.sleep(0.5)
    title = chaque.find_element_by_class_name('jobtitle').text
    if title == False:
        title = 'None'
    #Scraping le nom de la boite sinon rien 
    try:
        boite = chaque.find_element_by_class_name('company').text
    except:
        boite = 'None'
    #Scraping le Ville sinon rien 
    try:
        city = chaque.find_element_by_class_name('location').text
    except:
        city = 'None'
    #Scraping le salaire sinon rien 
    try:
        salary = chaque.find_element_by_class_name('salaryText').text
    except:
        salary = 'None'
    #Scraping le type de contrat sinon chercher une autre position 
    try:
        contrat = browser.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[3]/div/div[1]/div[1]/div[2]/div[3]/span').text
        if contrat == salary:
            contrat = browser.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table/tbody/tr/td[3]/div/div[1]/div[1]/div/div[3]/span[2]').text
    except: 
        try:
            contrat = browser.find_element_by_xpath('//*[@id="vjs-tab-job"]/div[1]/div[2]/span[2]').text
        except:
            contrat = None
    #Scraping le description sinon rien 
    try:
        describe = chaque.find_element_by_class_name('summary').text
    except:
        describe = 'None'
    #Scraping le date de publication sinon rien 
    try:
        publish_date = chaque.find_element_by_class_name('date').text
    except:
        try:
            publish_date = browser.find_element_by_xpath(' //*[@id="vjs-footer"]/div[1]/div/span[1]').text
        except:
            publish_date = 'None'
    df = df.append({"Titre" : title,"Entreprise" : boite,"Ville" : city,"Salaire": salary, "Type de contrat" : contrat, "Descriptif du poste" : describe, "Date de publication" : publish_date}, ignore_index=True)
    #Page Suivante
"""try:
    #Passer à la page suivante.
    next_button = browser.find_element_by_class_name("np")
    next_button.click()
    time.sleep(5)
except: #block à exécuter si on se trouve sur la dernière page des résultats
    browser.quit() #Attention ça ferme la fênetre
    break"""
# Out:
# 'try:\n    #Passer à la page suivante.\n    next_button = browser.find_element_by_class_name("np")\n    next_button.click()\n    time.sleep(5)\nexcept: #block à exécuter si on se trouve sur la dernière page des résultats\n    browser.quit() #Attention ça ferme la fênetre\n    break'

# %%
browser.find_element_by_class_name('date').text
# Out:
# 'il y a 3 jours'

# %%
browser.find_elements_by_class_name('jobtitle')[3].text
# Out:
# 'Fleet Manager - Junior'

# %%
browser.find_elements_by_class_name('result')[0].text

# %%
df
# Out:
#                                                 Titre  \
# 0                  Responsable Pôle Dev & intégration
# 1                 Développeur Web (F/H) DEV-PRE-PNL80
# 2   Alternance - Assist. développement de POC (Pro...
# 3               Webmaster / Webdesigner/ Informatique
# 4                        Développeur Back-end PHP F/H
# 5                          Data Engineer - Python H/F
# 6   DEV FULLSTACK PHP SF |PARIS 16E | BELLE OPPORT...
# 7                                   Dev Full Stack ��
# 8   STAGE ASSISTANT BIZ DEV / COMMERCIAL Basé à Paris
# 9                                    PYTHON DEV - F/H
# 10             Développeur Junior (ReactJS / Node.js)
# 11                                  Stagiaire Dev Web
# 12                                        Data Hunter
# 13                International Sales Accelerator H/F
# 14             CDI - Business Developer International
# 15   Dev fullstack VueJS/Java Spring boot / Freelance
# 16                             Fleet Manager - Junior
# 17                           Customer Success Officer
#
#                     Entreprise                   Ville  \
# 0                          MKI  Neuilly-sur-Seine (92)
# 1                     Premista              Paris (75)
# 2                        Total          Hauts-de-Seine
# 3           Studio des Parfums           Paris 4e (75)
# 4                  AdopteUnMec              Paris (75)
# 5                  Data Impact          Paris 10e (75)
# 6                      In-Team              Paris (75)
# 7                        Libon              Paris (75)
# 8                         LEOO              Paris (75)
# 9                   Ingeniance              Paris (75)
# 10                       AKOYA              Paris (75)
# 11  DreamCentury Entertainment              Paris (75)
# 12                OpenDataSoft              Paris (75)
# 13                   JobTeaser              Paris (75)
# 14                  GlobalExam              Paris (75)
# 15               warren walter              Paris (75)
# 16                  deliver.ee              Paris (75)
# 17                 Chronotruck          Paris 1er (75)
#
#                        Salaire  \
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# 5                         None
# 6   43 000 € - 75 000 € par an
# 7   4 000 € - 5 500 € par mois
# 8             3,75 € par heure
# 9                         None
# 10                        None
# 11    800 € - 1 500 € par mois
# 12                        None
# 13                        None
# 14  35 000 € - 45 000 € par an
# 15           500 € par semaine
# 16              700 € par mois
# 17  28 000 € - 33 000 € par an
#
#                                       Type de contrat  \
# 0                                                 CDI
# 1                                                 CDI
# 2                          Apprentissage, Contrat pro
# 3   Temps plein, Temps partiel, CDD, Stage, Freela...
# 4                                                 CDI
# 5                                    Temps plein, CDI
# 6                          43 000 € - 75 000 € par an
# 7                                    Temps plein, CDI
# 8                                               Stage
# 9                                                 CDI
# 10                                              Stage
# 11                                 Temps plein, Stage
# 12                                                CDI
# 13                                               None
# 14                                                CDI
# 15               Temps plein, Freelance / Indépendant
# 16                                              Stage
# 17                                   Temps plein, CDI
#
#                                   Descriptif du poste Date de publication
# 0   Responsable pôle dev & intégration ou similair...                None
# 1   Groupe PREMISTA, leader français du regroupeme...                None
# 2   Vous réalisez de la veille technologique en te...                None
# 3   Studio de création spécialisé en parfum sur me...    il y a 23 heures
# 4   Le poste (Dev Back-end PHP)*. Nous recherchons...                None
# 5   En pleine croissance, notamment à l’internatio...                None
# 6   Parce que votre passion pour les technologies ...      il y a 11 mois
# 7   Dev full stack ou similaire: Par ailleurs, nou...     il y a 12 jours
# 8   Vous êtes en école de commerce, vous recherche...    il y a 18 heures
# 9   De l'écriture des normes de dev de l'équipe. N...       il y a 1 jour
# 10  1 CTO, 1 dev backend, 1 dev frontend. En compl...       il y a 1 jour
# 11  Au sein d'une équipe jeune, dans une société à...       il y a 9 mois
# 12  Entretien technique avec data hunter et dev (1...    il y a 13 heures
# 13  De formation bac + 3 à Bac +5, tu veux découvr...      il y a 3 jours
# 14  On ne naît pas Super Biz Dev, on le devient ! ...      il y a 7 jours
# 15  DEV, QA) en tant que Dev fullstack pour travai...       il y a 1 jour
# 16  Tu travailleras avec les différentes équipes (...                None
# 17  Chronotruck est une plateforme web et mobile d...                None

# %%
def restart_or_continue():
    while True:
        try:
            #Passer à la page suivante.
            next_button = browser.find_element_by_class_name("np")
            next_button.click()
            time.sleep(5)
        except: #block à exécuter si on se trouve sur la dernière page des résultats
            return_to_start = browser.find_element_by_xpath("/html/body/table[1]/tbody/tr/td/table/tbody/tr/td[1]/a/img")
            retrun_to_start.click()
            break
            
#browser.quit() #Attention ça ferme la fênetre

# %%
#Page Suivante
try:
    #Passer à la page suivante.
    next_button = browser.find_element_by_class_name("np")
    next_button.click()
    time.sleep(5)
except: #block à exécuter si on se trouve sur la dernière page des résultats
    browser.quit() #Attention ça ferme la fênetre
    break
