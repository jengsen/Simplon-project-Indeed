# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Les skills (tagged)

# %%
skills = set(sorted(pd.read_csv("tagged.txt", header=None)[0]))

# %%
import re
def parse_salary(salary):
    
    # Supprime les espaces dans les valeurs de salaires
    
    sal = salary.replace(' ', '')
    
    # PENSER AU NAN
    
    ### if salary == nan
    
    ########### On parse si le salaire est "par an"
    
    if 'par an' in salary:
        if '-' in salary:
            x = re.findall('\d+', sal)
            avg = (int(x[0]) + int(x[1]))/(len(x))
            return [int(x[0]),int(x[1])] # je retourne le tableau avec la fourchette de salaire en int (au lieu d'avg)
        else:
            x = re.findall('\d+', sal)
            return int(x[0])
        
    ########## Sinon on parse si le salaire est "par mois"
    
    elif 'par mois' in salary:
        if '-' in salary:
            x = re.findall('\d+', sal)
            avg = (int(x[0]) + int(x[1]))/(len(x))
            return (avg * 12) 
        else:
            x = re.findall('\d+', sal)
            return (int(x[0]) * 12)
    
    ########## Sinon on parse si le salaire est "par semaine"
    
    elif 'par semaine' in salary:
        if '-' in salary:
            x = re.findall('\d+', sal)
            avg = (int(x[0]) + int(x[1]))/(len(x))
            return (avg * 4 * 12) 
        else:
            x = re.findall('\d+', sal)
            return (int(x[0]) * 4 * 12)
    
    
    ########## Sinon on parse si le salaire est "par jour"
    
    elif 'par jour' in salary:
        if '-' in salary:
            x = re.findall('\d+', sal)
            avg = (int(x[0]) + int(x[1]))/(len(x))
            return (avg * 20 * 12)
        else:
            x = re.findall('\d+', sal)
            return (int(x[0]) * 20 * 12)
    
    ########## Sinon on parse si le salaire est "heure"
    
    elif 'par heure' in salary:
        if '-' in salary:
            x = re.findall('\d+', sal)
            avg = (int(x[0]) + int(x[1]))/(len(x))
            return (avg * 35 * 4 * 12)
        else:
            x = re.findall('\d+', sal)
            return (int(x[0]) * 35 * 4 * 12)

# %% [markdown]
# # Data

# %%
data = pd.read_json("./BDD_14_10_2019.json", lines=True, encoding='utf8')
data
# Out:
#       Date_de_publication                                Descriptif_du_poste  \
# 0          il y a 4 jours  #JobAlert #Stats #DataScientist #Nantes #Mérie...
# 1          il y a 4 jours  A ce titre, vos principales missions sont les ...
# 2          il y a 4 jours  LE LEADER FRANCAIS DE LA DATA RECRUTE.Rejoindr...
# 3          il y a 4 jours  Le programme data du groupe Maisons du Monde a...
# 4          il y a 4 jours  KANDY, basée à Treillières, près de Nantes (44...
# 5          il y a 4 jours  A compétences égales, le poste est ouvert aux ...
# 6          il y a 4 jours  Naval Group, leader européen du naval de défen...
# 7          il y a 4 jours  A ce titre, vos principales missions sont les ...
# 8          il y a 4 jours  THE FRENCH LEADER OF THE DATA RECRUITS.\nJoini...
# 9          il y a 4 jours  Contexte du poste :\nLa donnée vous inspire ? ...
# 10                         Nous recherchons un consultant Data Engineer p...
# 11         il y a 4 jours  #JobAlert #Stats #DataScientist #Nantes #Mérie...
# 12         il y a 4 jours  A ce titre, vos principales missions sont les ...
# 13         il y a 4 jours  A compétences égales, le poste est ouvert aux ...
# 14         il y a 4 jours  Case Law Analytics, startup nantaise spécialis...
# 15         il y a 4 jours  Stage_Consultant Data Scientist (H/F)\n\nDescr...
# 16         il y a 4 jours  LE LEADER FRANCAIS DE LA DATA RECRUTE.Rejoindr...
# 17        il y a 19 jours  Job ref: N/A\nThe Institut Laue-Langevin (ILL)...
# 18        il y a 19 jours  THE FRENCH LEADER OF THE DATA RECRUITS.\nJoini...
# 19        il y a 19 jours  Je recherche pour l’un de mes clients, grand c...
# 20        il y a 19 jours  Pour notre client du secteur bancaire, nous re...
# 21        il y a 19 jours  Job Description\n\nAu sein du pôle Operations,...
# 22        il y a 19 jours  Job Description\n\nYou will ensure the buildin...
# 23        il y a 19 jours  DESCRIPTION DE L'OFFRE\nExternatic, c'est le p...
# 24        il y a 19 jours  Description de l’entreprise\nCapgemini à Nante...
# 25        il y a 19 jours  Please note that we can only consider candidat...
# 26         il y a 2 jours  Vous êtes en recherche d’une nouvelle aventure...
# 27         il y a 2 jours  LE LEADER FRANCAIS DE LA DATA RECRUTE.Rejoindr...
# 28         il y a 2 jours  Sopra Steria, fort de près de 42 000 collabora...
# 29         il y a 2 jours  Descriptif du Poste :\nVous aurez pour mission...
# ...                   ...                                                ...
# 13259      il y a 3 jours  Company Overview\nCompany Overview\n\nSAS Inst...
# 13260      il y a 3 jours  Œuvrant parmi les acteurs les plus prestigieux...
# 13261      il y a 3 jours  Imaginez demain...\n\nDans le cadre de la stra...
# 13262      il y a 3 jours  Mission\nPerfectSight est le premier intégrate...
# 13263      il y a 3 jours  Haier Europe fait partie de Haier Smart Home, ...
# 13264      il y a 3 jours  Notre entreprise est une start-up récemment cr...
# 13265      il y a 3 jours  Le contenu du poste est libellé en anglais car...
# 13266      il y a 3 jours  Imaginez demain ...\nAu sein du département R&...
# 13267      il y a 3 jours  Stuart is a leading last mile delivery platfor...
# 13268      il y a 3 jours  The successful candidate will be progressive, ...
# 13269      il y a 3 jours  Mission\nVous intégrez le département KYC/ECM ...
# 13270      il y a 3 jours  Le groupe GEFCO est un leader mondial de la su...
# 13271      il y a 3 jours  Imaginez demain ...\n\nL’équipe EXALEAD NETVIB...
# 13272      il y a 3 jours  About us\n\nAs one of the world's largest inde...
# 13273       il y a 1 jour  Position Description:\nCGI Retail, Luxe & Manu...
# 13274       il y a 1 jour  Dans le cadre de notre développement, nous rec...
# 13275       il y a 1 jour  Airbus Defence and Space SAS\nAirbus is a glob...
# 13276       il y a 1 jour  Company description:\nFounded in 1977, Eutelsa...
# 13277       il y a 1 jour  Rattaché à la Direction des Systèmes d’Informa...
# 13278       il y a 1 jour  Line of Service\nInternal Firm Services\nIndus...
# 13279       il y a 1 jour  FRS - DANONE SA,a subsidiary of Danone, is loo...
# 13280       il y a 1 jour  Danone recherche Digital & Process Supply Chai...
# 13281     il y a 16 jours  Missions Sous l’autorité du Directeur des Syst...
# 13282     il y a 16 jours  Description du poste :\nVous dépendrez directe...
# 13283      il y a 10 mois  Rattaché au DAF France vous aurez la responsab...
# 13284      il y a 10 mois  About Mixpanel:\nAt Mixpanel, our mission is t...
# 13285      il y a 10 mois  CCH Tagetik - We understand the complex challe...
# 13286       il y a 8 mois  Travailler sur des missions variées, stratégiq...
# 13287       il y a 8 mois  The Moody's Analytics Sales Team is composed o...
# 13288       il y a 8 mois  Internship/stage Online Assistant MAC - EMEA\n...
#
#                                     Entreprise                     Salaire  \
# 0      SILLIKER - MERIEUX NUTRISCIENCES FRANCE             40 000 € par an
# 1                               Page Personnel                        None
# 2                                       Umanis                        None
# 3                             Maisons du Monde                        None
# 4                                        KANDY  30 000 € - 40 000 € par an
# 5                                EPSILON-ALCEN  30 000 € - 50 000 € par an
# 6                                  Naval Group                        None
# 7                            Page Personnel FR                        None
# 8                                       Umanis                        None
# 9                                        ippon                        None
# 10                          CS Group Solutions                        None
# 11     SILLIKER - MERIEUX NUTRISCIENCES FRANCE             40 000 € par an
# 12                              Page Personnel                        None
# 13                               EPSILON-ALCEN  30 000 € - 50 000 € par an
# 14                          Case Law Analytics                        None
# 15                                         CGI                        None
# 16                                      Umanis                        None
# 17                      Institut Laue-Langevin                        None
# 18                                      Umanis                        None
# 19                                     Almatek                        None
# 20                                        INTM                        None
# 21                                     iAdvize                        None
# 22                                     iAdvize                        None
# 23                                  EXTERNATIC                        None
# 24                                   Capgemini                        None
# 25                                The AKKAdemy                        None
# 26                             NOVA TECHNOLOGY                        None
# 27                                      Umanis                        None
# 28                                Sopra Steria                        None
# 29                             NOVA Technology                        None
# ...                                        ...                         ...
# 13259                            SAS Institute                        None
# 13260                                 HURRYMAN                        None
# 13261                        Dassault Systèmes                        None
# 13262                            Perfect Sight                        None
# 13263                                    Haier                        None
# 13264                                La Relève      700 € - 900 € par mois
# 13265                                   Sanofi                        None
# 13266                        Dassault Systèmes                        None
# 13267                                   Stuart                        None
# 13268                      Amazon EU SARL (FR)                        None
# 13269                         Société Générale                        None
# 13270                                    Gefco                        None
# 13271                        Dassault Systèmes                        None
# 13272                          Rothschild & Co                        None
# 13273                          CGI Group, Inc.                        None
# 13274                           Robert Walters                        None
# 13275                                   Airbus                        None
# 13276                                 EUTELSAT                        None
# 13277                            TOMORROW JOBS                        None
# 13278                                      PwC                        None
# 13279                                   Danone                        None
# 13280                                   Danone                        None
# 13281        Mairie de FONTENAY-SOUS-BOIS (94)                        None
# 13282                                   Keyrus                        None
# 13283                                   KEYRUS                        None
# 13284                                 Mixpanel                        None
# 13285                           Wolters Kluwer                        None
# 13286                                      S&H                        None
# 13287                        Moody's Analytics                        None
# 13288                   Estée Lauder Companies                        None
#
#                 Scrapped_job Scrapped_location  \
# 0             data scientist            Nantes
# 1             data scientist            Nantes
# 2             data scientist            Nantes
# 3             data scientist            Nantes
# 4             data scientist            Nantes
# 5             data scientist            Nantes
# 6             data scientist            Nantes
# 7             data scientist            Nantes
# 8             data scientist            Nantes
# 9             data scientist            Nantes
# 10            data scientist            Nantes
# 11            data scientist            Nantes
# 12            data scientist            Nantes
# 13            data scientist            Nantes
# 14            data scientist            Nantes
# 15            data scientist            Nantes
# 16            data scientist            Nantes
# 17            data scientist            Nantes
# 18            data scientist            Nantes
# 19            data scientist            Nantes
# 20            data scientist            Nantes
# 21            data scientist            Nantes
# 22            data scientist            Nantes
# 23            data scientist            Nantes
# 24            data scientist            Nantes
# 25            data scientist            Nantes
# 26              data analyst            Nantes
# 27              data analyst            Nantes
# 28              data analyst            Nantes
# 29              data analyst            Nantes
# ...                      ...               ...
# 13259  business intelligence             Paris
# 13260  business intelligence             Paris
# 13261  business intelligence             Paris
# 13262  business intelligence             Paris
# 13263  business intelligence             Paris
# 13264  business intelligence             Paris
# 13265  business intelligence             Paris
# 13266  business intelligence             Paris
# 13267  business intelligence             Paris
# 13268  business intelligence             Paris
# 13269  business intelligence             Paris
# 13270  business intelligence             Paris
# 13271  business intelligence             Paris
# 13272  business intelligence             Paris
# 13273  business intelligence             Paris
# 13274  business intelligence             Paris
# 13275  business intelligence             Paris
# 13276  business intelligence             Paris
# 13277  business intelligence             Paris
# 13278  business intelligence             Paris
# 13279  business intelligence             Paris
# 13280  business intelligence             Paris
# 13281  business intelligence             Paris
# 13282  business intelligence             Paris
# 13283  business intelligence             Paris
# 13284  business intelligence             Paris
# 13285  business intelligence             Paris
# 13286  business intelligence             Paris
# 13287  business intelligence             Paris
# 13288  business intelligence             Paris
#
#                                                    Titre  \
# 0      Data Scientist H/F - BIOFORTIS - CDI - Saint-H...
# 1                          Data Scientist en Pistage H/F
# 2                     CONSULTANT DATA SCIENCE H/F RENNES
# 3                          Data scientist (h/f) - Nantes
# 4                                     Data Scientist H/F
# 5                           Ingénieur Data Scientist H/F
# 6                          Data Scientist en Pistage H/F
# 7      Data Scientist en Pistage H/F - Naval Group, l...
# 8                     DATA SCIENTIST confirmé H/F NANTES
# 9                                  Consultant Data (h/f)
# 10                             Data Engineer / Freelance
# 11     Data Scientist H/F - BIOFORTIS - CDI - Saint-H...
# 12                         Data Scientist en Pistage H/F
# 13                          Ingénieur Data Scientist H/F
# 14                               Ingénieur R&D NLP - F/H
# 15                 Stage_Consultant Data Scientist (H/F)
# 16                      DATA SCIENTIST JUNIOR H/F NANTES
# 17                              Research Scientist (F/M)
# 18                    CONSULTANT DATA SCIENCE H/F RENNES
# 19     Un développeur python spark + Git sur Nantes /...
# 20                           Ingénieur de production F/H
# 21                           Développeur Java/Apex (H/F)
# 22                            Senior Data Engineer (M/F)
# 23                                   Architecte Data H/F
# 24      Consultant Innovation ( data, IA, …)_ Nantes H/F
# 25     Ingénieur Junior Developpement Software (Reloc...
# 26                            DATA analyste informatique
# 27     Analyste Programmeur Mainframe H/F Vannes /Nantes
# 28                    Chef de Projet Expérimenté CDI H/F
# 29                                          DATA ANALYST
# ...                                                  ...
# 13259               Account Executive - Financial Sector
# 13260    Ingénieur en Transformation Technologique (H/F)
# 13261  STAGE – Analyste Market & Business Development...
# 13262         Stage de pré-embauche - Consultant EPM H/F
# 13263                Chef de Produit Senior Lavage (H/F)
# 13264  Stage - Analyste en intelligence économique et...
# 13265                            TM1 Service Manager M/F
# 13266  STAGE - Ingénieur Développement d'une applica...
# 13267                                 Chief Data Officer
# 13268                  Senior Employee Relations Manager
# 13269                  Stage - Expert de processus-(H/F)
# 13270               Analyste supply chain - V.I.E. (H/F)
# 13271                      Portfolio Manager R&D EXALEAD
# 13272                           Gestionnaire Back Office
# 13273    Consultant Expert Big Data – Data Analytics H/F
# 13274                          Business Developer IT H/F
# 13275  Project Manager Multi Int – Secteur Défense (h/f)
# 13276  INTERNSHIP - Marketing and Sales Database Mana...
# 13277         CONSULTANT INTERNE / CHEF DE PROJET IT F/H
# 13278  Chargé de la qualité des données @PwC Levalloi...
# 13279                 Danone IS/IT - IS Treasury Manager
# 13280             Digital & Process Supply Chain Manager
# 13281                               Chef de projet (h/f)
# 13282                      Chef de Projet BI H/F (Paris)
# 13283            Directeur Contrôle de Gestion & ADV F/H
# 13284                                     Sales Engineer
# 13285              CCH Tagetik - Inside Sales Specialist
# 13286                  STAGE TECHNIQUE HCM TOOLKIT (H/F)
# 13287                    Solution Specialist (Pre Sales)
# 13288       Internship/stage Online Assistant MAC - EMEA
#
#                             Type_de_contrat                     Ville  \
# 0                                      None       Saint-Herblain (44)
# 1                                      None               Nantes (44)
# 2                                      None          Loire-Atlantique
# 3                                      None               Vertou (44)
# 4                                      None          Treillières (44)
# 5                                      None               Nantes (44)
# 6                                      None               Nantes (44)
# 7                                      None               Nantes (44)
# 8                                      None       Saint-Herblain (44)
# 9                                      None               Nantes (44)
# 10                                     None
# 11                                      CDI       Saint-Herblain (44)
# 12                                      CDI               Nantes (44)
# 13                                      CDI               Nantes (44)
# 14                         Temps plein, CDI               Nantes (44)
# 15                                    Stage                    France
# 16                                    Stage          Loire-Atlantique
# 17                                     None                    France
# 18                                     None       Saint-Herblain (44)
# 19     Temps plein, Freelance / Indépendant               Nantes (44)
# 20                                      CDI               Nantes (44)
# 21                                      CDI               Nantes (44)
# 22                                      CDI               Nantes (44)
# 23                                      CDI               Nantes (44)
# 24                                      CDI          Pays de la Loire
# 25                  Temps plein, Autre, CDI                    France
# 26                                     None               Nantes (44)
# 27                                     None          Loire-Atlantique
# 28                                     None          Loire-Atlantique
# 29                                      CDI               Nantes (44)
# ...                                     ...                       ...
# 13259                      1 120 € par mois               Yerres (91)
# 13260                                   CDI                Paris (75)
# 13261                                 Stage  Vélizy-Villacoublay (78)
# 13262                                 Stage                Paris (75)
# 13263                      Temps plein, CDI          Saint-Denis (93)
# 13264                                 Stage                Paris (75)
# 13265                                   CDI               Antony (92)
# 13266                                 Stage  Vélizy-Villacoublay (78)
# 13267                                 Stage                Paris (75)
# 13268                                 Stage                Paris (75)
# 13269                                 Stage           La Défense (92)
# 13270                      Temps plein, CDI           Courbevoie (92)
# 13271                      Temps plein, CDI                Paris (75)
# 13272                      Temps plein, CDI                Paris (75)
# 13273                                   CDI                Paris (75)
# 13274                                   CDI                Paris (75)
# 13275                                   CDI                Paris (75)
# 13276                                 Stage            Paris 15e (75)
# 13277                                   CDI              Puteaux (92)
# 13278                                   CDI     Levallois-Perret (92)
# 13279                                   CDI           Saint-Ouen (93)
# 13280                                   CDI               Rungis (94)
# 13281                                   CDI   Fontenay-sous-Bois (94)
# 13282                                   CDI                Paris (75)
# 13283                                   CDI     Levallois-Perret (92)
# 13284                                   CDI                Paris (75)
# 13285                                   CDI                Paris (75)
# 13286                    Temps plein, Stage                Paris (75)
# 13287                    Temps plein, Stage                Paris (75)
# 13288                                 Stage                Paris (75)
#
#                                         _id
# 0      {'$oid': '5d9b7361130e0588f823d767'}
# 1      {'$oid': '5d9b7361130e0588f823d768'}
# 2      {'$oid': '5d9b7362130e0588f823d769'}
# 3      {'$oid': '5d9b7363130e0588f823d76a'}
# 4      {'$oid': '5d9b7363130e0588f823d76b'}
# 5      {'$oid': '5d9b7364130e0588f823d76c'}
# 6      {'$oid': '5d9b7365130e0588f823d76d'}
# 7      {'$oid': '5d9b7366130e0588f823d76e'}
# 8      {'$oid': '5d9b7367130e0588f823d76f'}
# 9      {'$oid': '5d9b7367130e0588f823d770'}
# 10     {'$oid': '5d9b7368130e0588f823d771'}
# 11     {'$oid': '5d9b7396ac24ca882fb2d285'}
# 12     {'$oid': '5d9b7397ac24ca882fb2d286'}
# 13     {'$oid': '5d9b739aac24ca882fb2d287'}
# 14     {'$oid': '5d9b739eac24ca882fb2d288'}
# 15     {'$oid': '5d9b739fac24ca882fb2d289'}
# 16     {'$oid': '5d9b73a0ac24ca882fb2d28a'}
# 17     {'$oid': '5d9b73a6ac24ca882fb2d28b'}
# 18     {'$oid': '5d9b73a6ac24ca882fb2d28c'}
# 19     {'$oid': '5d9b73a7ac24ca882fb2d28d'}
# 20     {'$oid': '5d9b73a8ac24ca882fb2d28e'}
# 21     {'$oid': '5d9b73a9ac24ca882fb2d28f'}
# 22     {'$oid': '5d9b73a9ac24ca882fb2d290'}
# 23     {'$oid': '5d9b73aaac24ca882fb2d291'}
# 24     {'$oid': '5d9b73abac24ca882fb2d292'}
# 25     {'$oid': '5d9b73acac24ca882fb2d293'}
# 26     {'$oid': '5d9b73bbac24ca882fb2d294'}
# 27     {'$oid': '5d9b73bbac24ca882fb2d295'}
# 28     {'$oid': '5d9b73bcac24ca882fb2d296'}
# 29     {'$oid': '5d9b73bdac24ca882fb2d297'}
# ...                                     ...
# 13259  {'$oid': '5da35952ac93ad11eb4e2d21'}
# 13260  {'$oid': '5da3595cac93ad11eb4e2d22'}
# 13261  {'$oid': '5da35961ac93ad11eb4e2d23'}
# 13262  {'$oid': '5da35964ac93ad11eb4e2d24'}
# 13263  {'$oid': '5da35967ac93ad11eb4e2d25'}
# 13264  {'$oid': '5da35973ac93ad11eb4e2d26'}
# 13265  {'$oid': '5da3597fac93ad11eb4e2d27'}
# 13266  {'$oid': '5da3598dac93ad11eb4e2d28'}
# 13267  {'$oid': '5da3598eac93ad11eb4e2d29'}
# 13268  {'$oid': '5da3598fac93ad11eb4e2d2a'}
# 13269  {'$oid': '5da35990ac93ad11eb4e2d2b'}
# 13270  {'$oid': '5da35992ac93ad11eb4e2d2c'}
# 13271  {'$oid': '5da35993ac93ad11eb4e2d2d'}
# 13272  {'$oid': '5da35994ac93ad11eb4e2d2e'}
# 13273  {'$oid': '5da359a3ac93ad11eb4e2d2f'}
# 13274  {'$oid': '5da359a4ac93ad11eb4e2d30'}
# 13275  {'$oid': '5da359a6ac93ad11eb4e2d31'}
# 13276  {'$oid': '5da359a7ac93ad11eb4e2d32'}
# 13277  {'$oid': '5da359a8ac93ad11eb4e2d33'}
# 13278  {'$oid': '5da359a9ac93ad11eb4e2d34'}
# 13279  {'$oid': '5da359aaac93ad11eb4e2d35'}
# 13280  {'$oid': '5da359abac93ad11eb4e2d36'}
# 13281  {'$oid': '5da359b9ac93ad11eb4e2d37'}
# 13282  {'$oid': '5da359beac93ad11eb4e2d38'}
# 13283  {'$oid': '5da359d3ac93ad11eb4e2d39'}
# 13284  {'$oid': '5da359d4ac93ad11eb4e2d3a'}
# 13285  {'$oid': '5da359d5ac93ad11eb4e2d3b'}
# 13286  {'$oid': '5da359e9ac93ad11eb4e2d3c'}
# 13287  {'$oid': '5da359ebac93ad11eb4e2d3d'}
# 13288  {'$oid': '5da359eeac93ad11eb4e2d3e'}
#
# [13289 rows x 10 columns]

# %%
#nombre de lignes avec salaire fixe
salary_without_range = []

for sal in data['Salaire']:
    if (sal != 'None') & ('-' not in sal):
        salary_without_range.append(sal)
        #print(sal)

len(salary_without_range)
# Out:
# 761

# %%
#data.loc[:,'Descriptif_du_poste', 'Salaire']

# %%
#to list

list_data = data.values.tolist()

# %%
#prends les colonnes description du poste et les salaires

mydata = [[ligne[3],ligne[1]] for ligne in list_data]
len(mydata)
# Out:
# 13289

# %%
#filtrer seulement les dannonces qui ont une description et un salaire

filtered = list(filter(lambda x: not (x[0]=="None" or x[1]=="None") , mydata))
len(filtered)
# Out:
# 2249

# %%
from gensim.utils import tokenize

#je tokenise la colonne description et je soustrait les skills + colonnes salaire, parse_salary et description
skills_extrated = list(map(lambda x: [x[0],parse_salary(x[0]),skills.intersection(set(tokenize(x[1],lowercase=True))), x[1] ], filtered))

# j'enlève les lignes qui ont 0 skills trouvées
skills_extrated  = list(filter(lambda x: len(x[2]) > 0 ,skills_extrated))
print(len(skills_extrated))

# recupère uniquement la colone skills
full_skills_list =list(map(lambda x: x[2], skills_extrated))

pd.DataFrame(skills_extrated)
# Out:
# 2112
#                                 0                1  \
# 0                 40 000 € par an            40000
# 1      30 000 € - 40 000 € par an   [30000, 40000]
# 2      30 000 € - 50 000 € par an   [30000, 50000]
# 3                 40 000 € par an            40000
# 4      30 000 € - 50 000 € par an   [30000, 50000]
# 5      30 000 € - 45 000 € par an   [30000, 45000]
# 6               420 € par semaine            20160
# 7                 44 000 € par an            44000
# 8      32 000 € - 45 000 € par an   [32000, 45000]
# 9      40 000 € - 50 000 € par an   [40000, 50000]
# 10     22 000 € - 28 000 € par an   [22000, 28000]
# 11     40 000 € - 50 000 € par an   [40000, 50000]
# 12               2 500 € par mois            30000
# 13                35 000 € par an            35000
# 14                40 000 € par an            40000
# 15     35 000 € - 50 000 € par an   [35000, 50000]
# 16     40 000 € - 55 000 € par an   [40000, 55000]
# 17     37 000 € - 40 000 € par an   [37000, 40000]
# 18     33 000 € - 38 000 € par an   [33000, 38000]
# 19     33 000 € - 40 000 € par an   [33000, 40000]
# 20                27 000 € par an            27000
# 21     34 000 € - 40 000 € par an   [34000, 40000]
# 22     35 000 € - 45 000 € par an   [35000, 45000]
# 23     40 000 € - 50 000 € par an   [40000, 50000]
# 24     35 000 € - 45 000 € par an   [35000, 45000]
# 25     35 000 € - 45 000 € par an   [35000, 45000]
# 26     35 000 € - 43 000 € par an   [35000, 43000]
# 27     35 000 € - 43 000 € par an   [35000, 43000]
# 28                40 000 € par an            40000
# 29     20 000 € - 40 000 € par an   [20000, 40000]
# ...                           ...              ...
# 2082       600 € - 800 € par mois             8400
# 2083              50 000 € par an            50000
# 2084             1 200 € par mois            14400
# 2085   38 000 € - 42 000 € par an   [38000, 42000]
# 2086   40 000 € - 45 000 € par an   [40000, 45000]
# 2087   30 000 € - 35 000 € par an   [30000, 35000]
# 2088            400 € par semaine            19200
# 2089              45 000 € par an            45000
# 2090            475 € par semaine            22800
# 2091   45 000 € - 60 000 € par an   [45000, 60000]
# 2092   35 000 € - 45 000 € par an   [35000, 45000]
# 2093   30 000 € - 50 000 € par an   [30000, 50000]
# 2094              40 000 € par an            40000
# 2095   40 000 € - 65 000 € par an   [40000, 65000]
# 2096             1 200 € par mois            14400
# 2097     900 € - 1 200 € par mois            12600
# 2098             1 200 € par mois            14400
# 2099   43 000 € - 46 000 € par an   [43000, 46000]
# 2100   3 500 € - 7 000 € par mois            63000
# 2101  90 000 € - 100 000 € par an  [90000, 100000]
# 2102              54 000 € par an            54000
# 2103             1 100 € par mois            13200
# 2104   35 000 € - 45 000 € par an   [35000, 45000]
# 2105   30 000 € - 33 000 € par an   [30000, 33000]
# 2106   40 000 € - 45 000 € par an   [40000, 45000]
# 2107             1 000 € par mois            12000
# 2108   40 000 € - 60 000 € par an   [40000, 60000]
# 2109   45 000 € - 55 000 € par an   [45000, 55000]
# 2110               400 € par jour            96000
# 2111   1 900 € - 2 300 € par mois            25200
#
#                                                       2  \
# 0     {workflows, r, learning, statistique, shiny, p...
# 1     {ux, r, numpy, learning, pandas, computing, fr...
# 2     {r, learning, pandas, html, rnn, c, statistiqu...
# 3     {r, workflows, learning, statistique, shiny, p...
# 4     {r, learning, pandas, html, rnn, c, statistiqu...
# 5                       {scrum, scripting, cloud, perl}
# 6                                      {etl, c, sql, r}
# 7                         {cloudera, ia, hadoop, spark}
# 8     {scrum, cloud, learning, c, agile, javascript,...
# 9     {node, autoscaling, cloud, react, aws, javascr...
# 10                           {erp, html, c, agile, css}
# 11         {arm, network, android, r, microej, mqtt, c}
# 12                             {c, postgre, php, mysql}
# 13       {poo, c, sgbd, php, mysql, agile, python, moe}
# 14         {jquery, hibernate, mvc, js, agile, angular}
# 15    {network, jira, android, r, microej, mqtt, amq...
# 16    {android, r, microej, mqtt, javafx, git, amqp,...
# 17    {javascript, angular, js, agile, framework, vu...
# 18    {node, html, javascript, postgresql, react, fr...
# 19                             {javascript, css, mysql}
# 20    {jquery, html, javascript, boostrap, framework...
# 21                                {scrum, scala, agile}
# 22                        {kubernetes, devops, symfony}
# 23                   {ux, html, crm, php, js, css, etl}
# 24                      {javascript, c, angular, agile}
# 25                        {react, selenium, cloud, php}
# 26    {node, react, git, c, js, agile, javascript, c...
# 27                    {react, c, js, agile, javascript}
# 28         {jquery, hibernate, mvc, js, agile, angular}
# 29    {html, cloud, javascript, angularjs, c, scrum,...
# ...                                                 ...
# 2082  {drupal, debian, wordpress, aws, wget, symfony...
# 2083  {node, android, react, flask, js, mongodb, pyt...
# 2084  {nlp, kubernetes, learning, git, bash, js, fra...
# 2085  {cloud, qemu, c, mysql, nodejs, framework, vm,...
# 2086                                      {webdev, sql}
# 2087  {scrum, jquery, html, responsive, drupal, xhtm...
# 2088  {laravel, elasticsearch, php, mysql, framework...
# 2089                         {r, c, ia, python, django}
# 2090  {redux, html, jira, angular, sass, git, c, agi...
# 2091  {jquery, react, weblogic, js, scrum, devops, o...
# 2092    {qml, matlab, git, c, agile, framework, python}
# 2093  {network, laravel, android, symfony, c, php, s...
# 2094  {html, network, android, symfony, drupal, git,...
# 2095  {qliksense, scripting, datastage, r, learning,...
# 2096  {nlp, r, flask, chatbot, learning, analytics, ...
# 2097                                   {pipedrive, crm}
# 2098                 {powerpoint, datastudio, bigquery}
# 2099                                       {powerpoint}
# 2100                                           {erp, c}
# 2101                                        {analytics}
# 2102  {scrum, cloudera, ml, bdd, learning, scikit, s...
# 2103  {etl, c, warehouse, scrum, python, postgresql,...
# 2104                                  {erp, cloud, sap}
# 2105                                         {sourcing}
# 2106  {erp, lumira, shellscript, git, sql, vbscript,...
# 2107                           {crm, c, datalake, btob}
# 2108                                    {c, trading, r}
# 2109                                  {erp, cloud, sap}
# 2110                  {reportings, etl, scripting, sql}
# 2111                                {german, motivated}
#
#                                                       3
# 0     #JobAlert #Stats #DataScientist #Nantes #Mérie...
# 1     KANDY, basée à Treillières, près de Nantes (44...
# 2     A compétences égales, le poste est ouvert aux ...
# 3     #JobAlert #Stats #DataScientist #Nantes #Mérie...
# 4     A compétences égales, le poste est ouvert aux ...
# 5     Votre Rôle, vos Responsabilités\nNous menons u...
# 6     Acteur européen de la transformation numérique...
# 7     Vous rejoindrez BEWIZYU dans un contexte de fo...
# 8     Capgemini recrute plusieurs développeurs JAVA ...
# 9     Seyos est un cabinet de recrutement spécialisé...
# 10    Éditeur de logiciels, nous développons en inte...
# 11    Profile\nDiplôme: Master en logiciel / électro...
# 12    Contexte\nDans le cadre du déploiement de l’en...
# 13    Description du poste\nBREIDIC, filiale agile e...
# 14    Hibernate / Spring / Angular / Java / Agile\nD...
# 15    Master en informatique\n3+ années d’expérience...
# 16    Master en informatique\n5 années d’expérience ...
# 17    Delia Technologies #LaDevOpsFamily\nDelia Tech...
# 18    Au sein d’une équipe technique de cinq personn...
# 19    Au sein d’une équipe technique de six développ...
# 20    #Informatique #Nantes #JobAlert #Mérieux #Biof...
# 21    A la fois cabinet de recrutement et société de...
# 22    Monsieur SLOOP est une agence digitale créée e...
# 23    L'entreprise\nEditeur logiciel basé à Nantes, ...
# 24    Delia Technologies #LaDevOpsFamily\nDelia, c’e...
# 25    Seyos est un cabinet de recrutement spécialisé...
# 26    Delia Technologies #LaDevOpsFamily\nDelia, c’e...
# 27    Delia Technologies #LaDevOpsFamily\nDelia, c’e...
# 28    Hibernate / Spring / Angular / Java / Agile\nD...
# 29    Votre Rôle, vos Responsabilités\nNous menons u...
# ...                                                 ...
# 2082  Italic, web studio :\nProducteurs de sites int...
# 2083  Le CRI recrute un.e développeur.se Android et ...
# 2084  Expérience souhaitée : Débutant (0 à 2 ans d'e...
# 2085  Chapelle Tech recherche un développeur C++ pou...
# 2086  Rédaction des livrables (SF, fiches de flux, ....
# 2087  ### DESCRIPTION DU POSTE\nIntégré à une équipe...
# 2088  PAS DE SOUS-TRAITANCE SVP !! Merci pour votre ...
# 2089  Développeur Python Full-Stack\nTYPE D’EMPLOI :...
# 2090  L’un de nos clients dans le secteur Bancaire r...
# 2091  Description du poste :\nPOESI, cabinet de cons...
# 2092  MISSIONS ET RESPONSABILITES :\nVous participer...
# 2093  Acteur de la transformation, TIMMXWARE apporte...
# 2094  Depuis 2002, TIMMXWARE c’est plus de 500 clien...
# 2095  ACT-ON est un cabinet de conseil RH et SIRH in...
# 2096  Tu recherches un stage en #DataScience ?\nTu s...
# 2097  Cette entreprise est une startup fondée par Hu...
# 2098  A propos de fifty-five :\nfifty-five accompagn...
# 2099  Fed Supply, cabinet de recrutement spécialisé,...
# 2100  ALTER SI est une jeune startup coopérative don...
# 2101  Notre Groupe de Conseil et de Services du Numé...
# 2102  DATAROX\nSociété spécialisée en conseil en Inf...
# 2103  La brigade de sapeurs-pompiers de Paris recher...
# 2104  SILERON est un cabinet de conseil internationa...
# 2105  SOFTEAM Data est l'entité spécialisée en Busin...
# 2106  LEON Recrutement, cabinet de chasse expert IT ...
# 2107  EXPLORE est un acteur majeur de la Data Intell...
# 2108  02 Sep Ingénieur développeur en Finance de Mar...
# 2109  SILERON est un cabinet de conseil internationa...
# 2110  AMOA Editique/Reporting/BI Editique / Demat / ...
# 2111  Description du poste\nDescription du poste\n[F...
#
# [2112 rows x 4 columns]

# %%
# applatissement de tout les skills avec doublons
#pour chaque ligne dans mon tableau full_skills_list parcours et pour chaque ligne parcours les skills et garde skills
skills_flatten = [skill for skills_line in full_skills_list for skill in skills_line]

# %%
#compte le nombre d'occurence d'un skill dans toutes les skills détectées
#renvoie un tuple avec le nombre de skills et le nom du skill
skillsByOcc = [(skills_flatten.count(skill), skill) for skill in set(skills_flatten)]

# %%
#visualiser l'occurence des skills 
#trier par la première colonne
skillsByOcc = sorted(skillsByOcc, key=lambda l: l[0] , reverse=True)

pd.DataFrame(skillsByOcc).to_csv('skills_by_occurrence.csv')

skillsByOcc
# Out:
# [(821, 'c'),
#  (650, 'agile'),
#  (595, 'javascript'),
#  (451, 'sql'),
#  (444, 'php'),
#  (422, 'html'),
#  (399, 'git'),
#  (397, 'css'),
#  (363, 'js'),
#  (343, 'angular'),
#  (314, 'r'),
#  (313, 'python'),
#  (300, 'scrum'),
#  (274, 'framework'),
#  (267, 'cloud'),
#  (265, 'react'),
#  (264, 'mysql'),
#  (214, 'symfony'),
#  (184, 'devops'),
#  (180, 'jenkins'),
#  (163, 'postgresql'),
#  (159, 'jquery'),
#  (153, 'nodejs'),
#  (146, 'ux'),
#  (146, 'aws'),
#  (140, 'node'),
#  (137, 'learning'),
#  (126, 'crm'),
#  (107, 'kubernetes'),
#  (107, 'android'),
#  (105, 'erp'),
#  (103, 'elasticsearch'),
#  (103, 'reactjs'),
#  (103, 'mvc'),
#  (102, 'gitlab'),
#  (98, 'oracle'),
#  (90, 'jira'),
#  (84, 'mongodb'),
#  (82, 'bootstrap'),
#  (82, 'hibernate'),
#  (80, 'github'),
#  (80, 'spark'),
#  (79, 'typescript'),
#  (74, 'bdd'),
#  (73, 'angularjs'),
#  (71, 'vuejs'),
#  (71, 'analytics'),
#  (69, 'etl'),
#  (69, 'scala'),
#  (63, 'nosql'),
#  (63, 'wordpress'),
#  (63, 'kanban'),
#  (62, 'hadoop'),
#  (61, 'jee'),
#  (58, 'webservices'),
#  (53, 'laravel'),
#  (50, 'ia'),
#  (48, 'graphql'),
#  (46, 'ajax'),
#  (45, 'redux'),
#  (44, 'responsive'),
#  (43, 'json'),
#  (43, 'sap'),
#  (42, 'swift'),
#  (41, 'roadmap'),
#  (41, 'drupal'),
#  (41, 'programming'),
#  (39, 'kotlin'),
#  (37, 'blockchain'),
#  (33, 'uml'),
#  (32, 'btob'),
#  (30, 'scripting'),
#  (30, 'debian'),
#  (30, 'django'),
#  (29, 'lamp'),
#  (28, 'poo'),
#  (28, 'sass'),
#  (28, 'windev'),
#  (27, 'nginx'),
#  (27, 'vb'),
#  (26, 'statistique'),
#  (26, 'versionning'),
#  (25, 'tfs'),
#  (25, 'sgbd'),
#  (25, 'prestashop'),
#  (24, 'versioning'),
#  (24, 'nlp'),
#  (24, 'slack'),
#  (23, 'photoshop'),
#  (22, 'powerpoint'),
#  (22, 'bigdata'),
#  (22, 'sourcing'),
#  (21, 'bash'),
#  (20, 'network'),
#  (20, 'dashboards'),
#  (19, 'pandas'),
#  (19, 'moe'),
#  (19, 'springboot'),
#  (19, 'devoxx'),
#  (18, 'ssrs'),
#  (18, 'mining'),
#  (18, 'postgre'),
#  (18, 'dataviz'),
#  (18, 'phpunit'),
#  (18, 'reportings'),
#  (17, 'intellij'),
#  (17, 'javaee'),
#  (17, 'postgres'),
#  (17, 'powerbi'),
#  (16, 'datalake'),
#  (16, 'ml'),
#  (16, 'cplusplus'),
#  (15, 'warehouse'),
#  (15, 'webmarketing'),
#  (14, 'emailing'),
#  (14, 'heroku'),
#  (14, 'selenium'),
#  (14, 'mvvm'),
#  (14, 'chatbot'),
#  (14, 'material'),
#  (14, 'workflows'),
#  (13, 'webdev'),
#  (13, 'processing'),
#  (13, 'golang'),
#  (13, 'grafana'),
#  (12, 'cloudera'),
#  (12, 'bigquery'),
#  (11, 'backbonejs'),
#  (11, 'perl'),
#  (11, 'hdfs'),
#  (11, 'mongo'),
#  (11, 'webdesign'),
#  (11, 'sqlserver'),
#  (11, 'hacking'),
#  (11, 'puppet'),
#  (10, 'dataflow'),
#  (10, 'twig'),
#  (10, 'wamp'),
#  (10, 'flask'),
#  (10, 'mapping'),
#  (10, 'basic'),
#  (10, 'ubuntu'),
#  (10, 'computing'),
#  (10, 'phpstorm'),
#  (10, 'trading'),
#  (10, 'scraping'),
#  (10, 'extjs'),
#  (10, 'orm'),
#  (9, 'twilio'),
#  (9, 'scikit'),
#  (9, 'webapi'),
#  (9, 'illustrator'),
#  (9, 'clouds'),
#  (9, 'mco'),
#  (9, 'gitflow'),
#  (9, 'webgl'),
#  (9, 'trello'),
#  (9, 'plugin'),
#  (9, 'sgbdr'),
#  (9, 'firmware'),
#  (9, 'fromscratch'),
#  (9, 'templates'),
#  (9, 'openapi'),
#  (9, 'clustering'),
#  (9, 'embedded'),
#  (8, 'tensorflow'),
#  (8, 'datawarehouse'),
#  (8, 'datamining'),
#  (8, 'vm'),
#  (8, 'containerisation'),
#  (8, 'rspec'),
#  (8, 'webservice'),
#  (8, 'backoffice'),
#  (8, 'svm'),
#  (8, 'xhtml'),
#  (8, 'dashboard'),
#  (7, 'database'),
#  (7, 'indesign'),
#  (7, 'symphony'),
#  (7, 'browserstack'),
#  (7, 'ssh'),
#  (7, 'wms'),
#  (7, 'benchmark'),
#  (7, 'arm'),
#  (7, 'numpy'),
#  (6, 'opengl'),
#  (6, 'mqtt'),
#  (6, 'joomla'),
#  (6, 'rgpd'),
#  (6, 'ecmascript'),
#  (6, 'jupyter'),
#  (6, 'hbase'),
#  (6, 'rxjava'),
#  (6, 'openstack'),
#  (6, 'bpm'),
#  (6, 'winform'),
#  (6, 'lstm'),
#  (6, 'benchmarks'),
#  (6, 'boosting'),
#  (6, 'rxjs'),
#  (6, 'ngrx'),
#  (6, 'dotnet'),
#  (6, 'cnn'),
#  (5, 'toeic'),
#  (5, 'german'),
#  (5, 'xsl'),
#  (5, 'qml'),
#  (5, 'pipedrive'),
#  (5, 'dao'),
#  (5, 'sqoop'),
#  (5, 'weblogic'),
#  (5, 'xaml'),
#  (5, 'requêtage'),
#  (5, 'xldeploy'),
#  (5, 'shiny'),
#  (5, 'keras'),
#  (5, 'matplotlib'),
#  (5, 'chatbots'),
#  (5, 'gentoo'),
#  (5, 'amqp'),
#  (4, 'matlab'),
#  (4, 'switcher'),
#  (4, 'webapps'),
#  (4, 'nltk'),
#  (4, 'cvs'),
#  (4, 'dashboarding'),
#  (4, 'gpao'),
#  (4, 'fpga'),
#  (4, 'rubyonrails'),
#  (4, 'ggplot'),
#  (4, 'soc'),
#  (4, 'delphi'),
#  (4, 'provisioning'),
#  (4, 'pentaho'),
#  (4, 'syslog'),
#  (4, 'teradata'),
#  (4, 'middlewares'),
#  (4, 'fedora'),
#  (4, 'mentoring'),
#  (4, 'vuex'),
#  (4, 'rsync'),
#  (4, 'seaborn'),
#  (4, 'wget'),
#  (4, 'databases'),
#  (4, 'freebsd'),
#  (4, 'openshift'),
#  (4, 'datadog'),
#  (4, 'boostrap'),
#  (4, 'mysys'),
#  (4, 'pluralsight'),
#  (4, 'cron'),
#  (4, 'datahub'),
#  (4, 'saltstack'),
#  (3, 'qliksense'),
#  (3, 'spss'),
#  (3, 'kubernete'),
#  (3, 'xgboost'),
#  (3, 'warehouses'),
#  (3, 'raspberry'),
#  (3, 'cdo'),
#  (3, 'uwp'),
#  (3, 'stackoverflow'),
#  (3, 'flink'),
#  (3, 'adserver'),
#  (3, 'camel'),
#  (3, 'rnn'),
#  (3, 'vbscript'),
#  (3, 'jms'),
#  (3, 'datagrip'),
#  (3, 'liquibase'),
#  (3, 'grails'),
#  (3, 'gerrit'),
#  (3, 'celery'),
#  (3, 'idl'),
#  (3, 'cakephp'),
#  (3, 'mageno'),
#  (3, 'sklearn'),
#  (3, 'datasciences'),
#  (3, 'testrails'),
#  (3, 'mapbox'),
#  (3, 'fasttext'),
#  (3, 'intelij'),
#  (3, 'debbuging'),
#  (3, 'mootools'),
#  (3, 'queries'),
#  (3, 'websocial'),
#  (3, 'debugger'),
#  (3, 'reactnative'),
#  (3, 'amoe'),
#  (3, 'wildfly'),
#  (3, 'mdx'),
#  (3, 'monogdb'),
#  (3, 'refactorer'),
#  (3, 'pivotal'),
#  (3, 'jwt'),
#  (3, 'openvibe'),
#  (3, 'lighttpd'),
#  (3, 'mssql'),
#  (3, 'plsql'),
#  (3, 'ssd'),
#  (3, 'visio'),
#  (3, 'vanillajs'),
#  (3, 'microej'),
#  (3, 'knox'),
#  (3, 'programing'),
#  (3, 'aspnet'),
#  (3, 'tsql'),
#  (3, 'canvas'),
#  (3, 'mapreduce'),
#  (3, 'motivated'),
#  (2, 'mpd'),
#  (2, 'datamarts'),
#  (2, 'osgi'),
#  (2, 'bigqueryml'),
#  (2, 'warehousing'),
#  (2, 'gdal'),
#  (2, 'activemq'),
#  (2, 'mysqli'),
#  (2, 'springbatch'),
#  (2, 'statistical'),
#  (2, 'addons'),
#  (2, 'couchdb'),
#  (2, 'coldfusion'),
#  (2, 'epitech'),
#  (2, 'sparkml'),
#  (2, 'datastudio'),
#  (2, 'dataquality'),
#  (2, 'portuguese'),
#  (2, 'expressjs'),
#  (2, 'scaler'),
#  (2, 'pgsql'),
#  (2, 'dl'),
#  (2, 'javaj'),
#  (2, 'versionnement'),
#  (2, 'biwee'),
#  (2, 'vnet'),
#  (2, 'openio'),
#  (2, 'mockups'),
#  (2, 'cloudification'),
#  (2, 'sqlite'),
#  (2, 'vsphere'),
#  (2, 'anchore'),
#  (2, 'osx'),
#  (2, 'wengo'),
#  (2, 'dareboost'),
#  (2, 'chinese'),
#  (2, 'rasterio'),
#  (2, 'netweaver'),
#  (2, 'aibuilder'),
#  (2, 'marketo'),
#  (2, 'snmp'),
#  (2, 'ovm'),
#  (2, 'statistics'),
#  (2, 'datavisualisation'),
#  (2, 'hololens'),
#  (2, 'sybase'),
#  (2, 'cobol'),
#  (2, 'yaml'),
#  (2, 'dotnetcore'),
#  (2, 'zimbra'),
#  (2, 'activex'),
#  (2, 'postman'),
#  (2, 'dplyr'),
#  (2, 'symfhony'),
#  (2, 'indricks'),
#  (2, 'mobx'),
#  (2, 'bundling'),
#  (2, 'tidyr'),
#  (2, 'anlalysis'),
#  (2, 'gdpr'),
#  (2, 'ltpx'),
#  (2, 'knn'),
#  (2, 'zendesk'),
#  (2, 'scrapings'),
#  (2, 'doxygen'),
#  (2, 'sqli'),
#  (2, 'localstorage'),
#  (2, 'readr'),
#  (2, 'gitops'),
#  (2, 'taln'),
#  (2, 'etcd'),
#  (2, 'webmapping'),
#  (2, 'sqs'),
#  (2, 'ntic'),
#  (2, 'avro'),
#  (2, 'javafx'),
#  (2, 'sccm'),
#  (2, 'débugages'),
#  (1, 'postgresqloutils'),
#  (1, 'gitla'),
#  (1, 'nextjs'),
#  (1, 'qemu'),
#  (1, 'virtualbox'),
#  (1, 'twimm'),
#  (1, 'poltly'),
#  (1, 'xslt'),
#  (1, 'mangodb'),
#  (1, 'contenurisation'),
#  (1, 'fetching'),
#  (1, 'yml'),
#  (1, 'arangodb'),
#  (1, 'datarobot'),
#  (1, 'emerchandising'),
#  (1, 'phileas'),
#  (1, 'postgrey'),
#  (1, 'coffeescript'),
#  (1, 'microdatas'),
#  (1, 'hmtl'),
#  (1, 'devsecops'),
#  (1, 'lazyload'),
#  (1, 'jacoco'),
#  (1, 'sublimetext'),
#  (1, 'datamodel'),
#  (1, 'datawarehouses'),
#  (1, 'mybatis'),
#  (1, 'mathematical'),
#  (1, 'appsync'),
#  (1, 'dataops'),
#  (1, 'elearning'),
#  (1, 'dockerisé'),
#  (1, 'oroplatform'),
#  (1, 'weboob'),
#  (1, 'reactstrap'),
#  (1, 'multitasking'),
#  (1, 'hybernate'),
#  (1, 'catia'),
#  (1, 'cloudstack'),
#  (1, 'alphaview'),
#  (1, 'mllib'),
#  (1, 'cloudcomputing'),
#  (1, 'awsavantages'),
#  (1, 'jhipster'),
#  (1, 'promisekit'),
#  (1, 'webflow'),
#  (1, 'econometrics'),
#  (1, 'mstest'),
#  (1, 'theano'),
#  (1, 'jsdom'),
#  (1, 'jvm'),
#  (1, 'railsversioning'),
#  (1, 'geofencing'),
#  (1, 'ocr'),
#  (1, 'statisticians'),
#  (1, 'louyetu'),
#  (1, 'soapcomp'),
#  (1, 'geojson'),
#  (1, 'dropwizard'),
#  (1, 'financing'),
#  (1, 'jitsi'),
#  (1, 'hacmp'),
#  (1, 'autoscaling'),
#  (1, 'entityframework'),
#  (1, 'datalakepour'),
#  (1, 'debugging'),
#  (1, 'restfull'),
#  (1, 'opentsdb'),
#  (1, 'rxswift'),
#  (1, 'javagv'),
#  (1, 'solving'),
#  (1, 'stackjava'),
#  (1, 'drush'),
#  (1, 'preferences'),
#  (1, 'multicloud'),
#  (1, 'gdb'),
#  (1, 'cleanswift'),
#  (1, 'rwd'),
#  (1, 'pdm'),
#  (1, 'firewall'),
#  (1, 'multicentre'),
#  (1, 'jqueryui'),
#  (1, 'cobian'),
#  (1, 'ldap'),
#  (1, 'bugzilla'),
#  (1, 'siem'),
#  (1, 'sparkline'),
#  (1, 'microframewok'),
#  (1, 'psql'),
#  (1, 'esx'),
#  (1, 'pyhon'),
#  (1, 'plotly'),
#  (1, 'shellscript'),
#  (1, 'processmaker'),
#  (1, 'webdesigners'),
#  (1, 'jsdéveloppement'),
#  (1, 'fhir'),
#  (1, 'objc'),
#  (1, 'nodesjs'),
#  (1, 'hosting'),
#  (1, 'multilocale'),
#  (1, 'thymeleaf'),
#  (1, 'devnodejs'),
#  (1, 'wsdl'),
#  (1, 'pycharm'),
#  (1, 'wampserver'),
#  (1, 'dotswift'),
#  (1, 'gcloud'),
#  (1, 'silverlight'),
#  (1, 'semrush'),
#  (1, 'rxandroid'),
#  (1, 'datadrivenmarketing'),
#  (1, 'postegresql'),
#  (1, 'netapp'),
#  (1, 'sparkr'),
#  (1, 'vtom'),
#  (1, 'autocad'),
#  (1, 'spendesk'),
#  (1, 'gpu'),
#  (1, 'persévérent'),
#  (1, 'dsstne'),
#  (1, 'flexbox'),
#  (1, 'webscraping'),
#  (1, 'vrf'),
#  (1, 'zipkin'),
#  (1, 'responsivedesign'),
#  (1, 'storybook'),
#  (1, 'kimayo'),
#  (1, 'pushy'),
#  (1, 'mpls'),
#  (1, 'ddos'),
#  (1, 'openvpn'),
#  (1, 'telephonie'),
#  (1, '_businessanalyst_'),
#  (1, 'regex'),
#  (1, 'bugfix'),
#  (1, 'salesforces'),
#  (1, 'reactful'),
#  (1, 'opencv'),
#  (1, 'stracth'),
#  (1, 'likewise'),
#  (1, 'openbsd'),
#  (1, 'wizaly'),
#  (1, 'devopsboard'),
#  (1, 'marsteller'),
#  (1, 'lumira'),
#  (1, 'awsworkflows'),
#  (1, 'sqlserveur'),
#  (1, 'businessintelligence'),
#  (1, 'jenkin'),
#  (1, 'procapital'),
#  (1, 'openldap'),
#  (1, 'salesfroce'),
#  (1, 'uikit'),
#  (1, 'phpmyadmin'),
#  (1, 'géodatabases'),
#  (1, 'visualmanagement'),
#  (1, 'tsdoc'),
#  (1, 'postgressql'),
#  (1, 'qlikvieuw'),
#  (1, 'datacore'),
#  (1, 'isomorphiques'),
#  (1, 'webscrapping'),
#  (1, 'ksql'),
#  (1, 'bootsrap'),
#  (1, 'hml'),
#  (1, 'msbi'),
#  (1, 'mentorship'),
#  (1, 'visualstudio'),
#  (1, 'rabitmq'),
#  (1, 'elephant'),
#  (1, 'directx'),
#  (1, 'datastage'),
#  (1, 'opencl'),
#  (1, 'xmetal'),
#  (1, 'agilitest'),
#  (1, 'hsrp'),
#  (1, 'dbpaas'),
#  (1, 'rstudio'),
#  (1, 'monitoriong'),
#  (1, 'stylelint'),
#  (1, 'gestform'),
#  (1, 'cloudconnaissance'),
#  (1, 'rtmp'),
#  (1, 'econometry'),
#  (1, 'enthusiastic'),
#  (1, 'qwamplifyest'),
#  (1, 'stochastic'),
#  (1, 'typesscript'),
#  (1, 'firebird'),
#  (1, 'corejava'),
#  (1, 'influxdb'),
#  (1, 'springsql'),
#  (1, 'affinity'),
#  (1, 'webanalytics'),
#  (1, 'mapinfo'),
#  (1, 'preact'),
#  (1, 'jshint'),
#  (1, 'relational'),
#  (1, 'daemons'),
#  (1, 'woocomerce'),
#  (1, 'graddle'),
#  (1, 'shinyr'),
#  (1, 'openmp'),
#  (1, 'extrapro'),
#  (1, 'hiveql'),
#  (1, 'apirest'),
#  (1, 'scheduler'),
#  (1, 'dhcp'),
#  (1, 'phptour'),
#  (1, '_angular_'),
#  (1, 'webdriver'),
#  (1, 'xnet'),
#  (1, 'ecard'),
#  (1, 'réact')]

# %% [markdown]
# # Stats

# %%
from statistics import mean, stdev

skills_set = set(skills_flatten)

skill_with_stat = []
for s in skillsByOcc:
    #cherche dans la description chaque skill et s'il trouve il renvoie la colonne salaire
    salaries_list_for_current_skill = [se[1] for se in skills_extrated if s[1] in se[2]]
    salaries = []
    #je parcours chaque salaire que j'ai eu et je le mets dans salaire
    for sa in salaries_list_for_current_skill:
        #si c'est un seul entier (salaire fixe) j'ajoute le même pour les deux colonnes
        if type(sa) == int:
            salaries.append(sa)
            salaries.append(sa) #attention biais
        else:
            #s'il y a une borne
            if type(sa) == list:
                salaries.append(sa[0]) #j'ajoute borne 1
                salaries.append(sa[1]) #j'ajoute la borne 2
    #si mon skill n'a pas plus que 10 annonce il l'exclue
    if len(salaries)>10:
        #filtre : enlève les salaires en dessous de 20000
        salaries =  list(filter(lambda x: x > 20000 ,salaries))
        #skill, cherche dans salaire le min, max, std, nb d'annonce qui ont cet skill 
        ecart = max(salaries)- min(salaries)

        skill_with_stat.append([s[1],min(salaries), max(salaries), int(mean(salaries)), int(stdev(salaries)), ecart, len(salaries_list_for_current_skill) ])   
    
    
df_skills_stats = pd.DataFrame(skill_with_stat)

df_skills_stats = df_skills_stats.set_axis(['skill', 'min', 'max', 'mean', 'stdev','plage', 'nb annonces'], axis=1, inplace=False)
df_skills_stats.to_csv("skills_stats_for_dataset_BDD_14_10_2019.csv")
df_skills_stats
# Out:
#                 skill    min     max   mean  stdev   plage  nb annonces
# 0                   c  20160   96000  42310  11222   75840          821
# 1               agile  20640  120000  45009  12513   99360          650
# 2          javascript  20640  120000  42147  10894   99360          595
# 3                 sql  20160  120000  43442  13224   99840          451
# 4                 php  20160   80000  39827   8864   59840          444
# 5                html  20160   80000  39908   9936   59840          422
# 6                 git  20640   96000  41569  10528   75360          399
# 7                 css  20160   84000  40028   9746   63840          397
# 8                  js  20160   84000  43972  10673   63840          363
# 9             angular  20640  120000  43218  11464   99360          343
# 10                  r  20160  120000  46279  13354   99840          314
# 11             python  20400  120000  47170  12759   99600          313
# 12              scrum  21600  120000  45271  12981   98400          300
# 13          framework  20640   96000  41677  11073   75360          274
# 14              cloud  22000  120000  46960  12634   98000          267
# 15              react  21600  120000  45328  12018   98400          265
# 16              mysql  21408   84000  39860   9325   62592          264
# 17            symfony  20160   75000  41100   9170   54840          214
# 18             devops  25000  120000  47196  12301   95000          184
# 19            jenkins  22800   75000  42876  10073   52200          180
# 20         postgresql  21408   84000  44464  11474   62592          163
# 21             jquery  20160   80000  39538  10441   59840          159
# 22             nodejs  21600   84000  45302  11219   62400          153
# 23                 ux  25000  100000  43826  12105   75000          146
# 24                aws  30000   80000  49659  10584   50000          146
# 25               node  25320   76800  45425  10504   51480          140
# 26           learning  21600   96000  49883  13654   74400          137
# 27                crm  21600   90000  44532  14229   68400          126
# 28         kubernetes  23040   80000  46400  10966   56960          107
# 29            android  21600  132000  44151  14750  110400          107
# ..                ...    ...     ...    ...    ...     ...          ...
# 168                vm  24000   55000  41142  11175   31000            8
# 169  containerisation  35000   60000  50625   6020   25000            8
# 170             rspec  35000   65000  51071   9840   30000            8
# 171        webservice  20640   50000  34942   9256   29360            8
# 172        backoffice  30000   80000  39416  15281   50000            8
# 173               svm  30000   60000  42500   9309   30000            8
# 174             xhtml  20640   42000  31325   8018   21360            8
# 175         dashboard  26400   55000  43280  10605   28600            8
# 176          database  23000   96000  43857  23441   73000            7
# 177          indesign  27000   36000  32000   3366    9000            7
# 178          symphony  28800   52000  36300   8362   23200            7
# 179               wms  32000   80000  41785  16455   48000            7
# 180               arm  30000   54000  42071   8137   24000            7
# 181             numpy  30000   65000  46614  11637   35000            7
# 182            opengl  30000   50000  38000   7745   20000            6
# 183              mqtt  32000   55000  41416   7476   23000            6
# 184              rgpd  24000  100000  56250  24481   76000            6
# 185        ecmascript  37000   65000  45750   7955   28000            6
# 186           jupyter  40700   70000  57760  10241   29300            6
# 187            rxjava  35000   60000  46250   8103   25000            6
# 188         openstack  30000   55000  39500   7306   25000            6
# 189               bpm  24000   55000  39833   9824   31000            6
# 190           winform  30000   50000  39700   7149   20000            6
# 191              lstm  30000   60000  44000  11737   30000            6
# 192        benchmarks  38000   80000  49916  14469   42000            6
# 193          boosting  40000   90000  68750  18231   50000            6
# 194              rxjs  37000   50000  44500   5435   13000            6
# 195              ngrx  40000   60000  47500   7229   20000            6
# 196            dotnet  30000   60000  44583  10326   30000            6
# 197               cnn  30000   60000  44000  11737   30000            6
#
# [198 rows x 7 columns]

# %% [markdown]
# # Calculer les coef et proba des skills

# %%
#calcul des écarts (minimun et maximun général de toutes les skills) de tous les minimuns et de tous les maximuns
ecarts = [d[5] for d in df_skills_stats.values]
min_e = min(ecarts)
max_e = max(ecarts)

#sum de colonne max
sum_max = sum([d[2] for d in df_skills_stats.values])
#sum de colonne min
sum_min =  sum([d[1] for d in df_skills_stats.values])

print(f"plage d'ecart min {min_e}€ max {max_e}€")

#new dataframe final
df_final = df_skills_stats.copy()

#j'ajoute la colonne coef à la position 6
df_final.insert(6, 'coef', [ecart / (max_e - min_e) for ecart in ecarts], True)
#j'ajoute la colonne proba à la position 7
df_final.insert(7, 'proba', [ecart / (sum_max - sum_min) for ecart in ecarts], True)

df_final
# Out:
# plage d'ecart min 9000€ max 110400€
#                 skill    min     max   mean  stdev   plage      coef  \
# 0                   c  20160   96000  42310  11222   75840  0.747929
# 1               agile  20640  120000  45009  12513   99360  0.979882
# 2          javascript  20640  120000  42147  10894   99360  0.979882
# 3                 sql  20160  120000  43442  13224   99840  0.984615
# 4                 php  20160   80000  39827   8864   59840  0.590138
# 5                html  20160   80000  39908   9936   59840  0.590138
# 6                 git  20640   96000  41569  10528   75360  0.743195
# 7                 css  20160   84000  40028   9746   63840  0.629586
# 8                  js  20160   84000  43972  10673   63840  0.629586
# 9             angular  20640  120000  43218  11464   99360  0.979882
# 10                  r  20160  120000  46279  13354   99840  0.984615
# 11             python  20400  120000  47170  12759   99600  0.982249
# 12              scrum  21600  120000  45271  12981   98400  0.970414
# 13          framework  20640   96000  41677  11073   75360  0.743195
# 14              cloud  22000  120000  46960  12634   98000  0.966469
# 15              react  21600  120000  45328  12018   98400  0.970414
# 16              mysql  21408   84000  39860   9325   62592  0.617278
# 17            symfony  20160   75000  41100   9170   54840  0.540828
# 18             devops  25000  120000  47196  12301   95000  0.936884
# 19            jenkins  22800   75000  42876  10073   52200  0.514793
# 20         postgresql  21408   84000  44464  11474   62592  0.617278
# 21             jquery  20160   80000  39538  10441   59840  0.590138
# 22             nodejs  21600   84000  45302  11219   62400  0.615385
# 23                 ux  25000  100000  43826  12105   75000  0.739645
# 24                aws  30000   80000  49659  10584   50000  0.493097
# 25               node  25320   76800  45425  10504   51480  0.507692
# 26           learning  21600   96000  49883  13654   74400  0.733728
# 27                crm  21600   90000  44532  14229   68400  0.674556
# 28         kubernetes  23040   80000  46400  10966   56960  0.561736
# 29            android  21600  132000  44151  14750  110400  1.088757
# ..                ...    ...     ...    ...    ...     ...       ...
# 168                vm  24000   55000  41142  11175   31000  0.305720
# 169  containerisation  35000   60000  50625   6020   25000  0.246548
# 170             rspec  35000   65000  51071   9840   30000  0.295858
# 171        webservice  20640   50000  34942   9256   29360  0.289546
# 172        backoffice  30000   80000  39416  15281   50000  0.493097
# 173               svm  30000   60000  42500   9309   30000  0.295858
# 174             xhtml  20640   42000  31325   8018   21360  0.210651
# 175         dashboard  26400   55000  43280  10605   28600  0.282051
# 176          database  23000   96000  43857  23441   73000  0.719921
# 177          indesign  27000   36000  32000   3366    9000  0.088757
# 178          symphony  28800   52000  36300   8362   23200  0.228797
# 179               wms  32000   80000  41785  16455   48000  0.473373
# 180               arm  30000   54000  42071   8137   24000  0.236686
# 181             numpy  30000   65000  46614  11637   35000  0.345168
# 182            opengl  30000   50000  38000   7745   20000  0.197239
# 183              mqtt  32000   55000  41416   7476   23000  0.226824
# 184              rgpd  24000  100000  56250  24481   76000  0.749507
# 185        ecmascript  37000   65000  45750   7955   28000  0.276134
# 186           jupyter  40700   70000  57760  10241   29300  0.288955
# 187            rxjava  35000   60000  46250   8103   25000  0.246548
# 188         openstack  30000   55000  39500   7306   25000  0.246548
# 189               bpm  24000   55000  39833   9824   31000  0.305720
# 190           winform  30000   50000  39700   7149   20000  0.197239
# 191              lstm  30000   60000  44000  11737   30000  0.295858
# 192        benchmarks  38000   80000  49916  14469   42000  0.414201
# 193          boosting  40000   90000  68750  18231   50000  0.493097
# 194              rxjs  37000   50000  44500   5435   13000  0.128205
# 195              ngrx  40000   60000  47500   7229   20000  0.197239
# 196            dotnet  30000   60000  44583  10326   30000  0.295858
# 197               cnn  30000   60000  44000  11737   30000  0.295858
#
#         proba  nb annonces
# 0    0.007864          821
# 1    0.010303          650
# 2    0.010303          595
# 3    0.010352          451
# 4    0.006205          444
# 5    0.006205          422
# 6    0.007814          399
# 7    0.006620          397
# 8    0.006620          363
# 9    0.010303          343
# 10   0.010352          314
# 11   0.010327          313
# 12   0.010203          300
# 13   0.007814          274
# 14   0.010162          267
# 15   0.010203          265
# 16   0.006490          264
# 17   0.005686          214
# 18   0.009850          184
# 19   0.005413          180
# 20   0.006490          163
# 21   0.006205          159
# 22   0.006470          153
# 23   0.007777          146
# 24   0.005184          146
# 25   0.005338          140
# 26   0.007714          137
# 27   0.007092          126
# 28   0.005906          107
# 29   0.011447          107
# ..        ...          ...
# 168  0.003214            8
# 169  0.002592            8
# 170  0.003111            8
# 171  0.003044            8
# 172  0.005184            8
# 173  0.003111            8
# 174  0.002215            8
# 175  0.002966            8
# 176  0.007569            7
# 177  0.000933            7
# 178  0.002406            7
# 179  0.004977            7
# 180  0.002489            7
# 181  0.003629            7
# 182  0.002074            6
# 183  0.002385            6
# 184  0.007880            6
# 185  0.002903            6
# 186  0.003038            6
# 187  0.002592            6
# 188  0.002592            6
# 189  0.003214            6
# 190  0.002074            6
# 191  0.003111            6
# 192  0.004355            6
# 193  0.005184            6
# 194  0.001348            6
# 195  0.002074            6
# 196  0.003111            6
# 197  0.003111            6
#
# [198 rows x 9 columns]

# %%
#vérification de la proba
col_proba = [d[7] for d in df_final.values]
sum_pro = sum(col_proba)
sum_pro
# Out:
# 1.0000000000000002

# %% [markdown]
# # Tableau avec 'salaire pertinant' (salaire prédit) en fonction des skills trouvés

# %%
#nouveau dataframe avec la colonne 'salary' et 'skills trouvés' dans skills_extracted
df_data = pd.DataFrame([[l[1], l[2]] for l in skills_extrated])
#je rajoute les titres des colonnes
df_data = df_data.set_axis(['salary', 'skills'], axis=1, inplace=False)

def predict_salary(row):
    #dans les stats de skills je cherche les skills qui ont été trouvés dans l'annonce dans le row en cours et récupère le coef correspondant au skill
    coef_avg = df_final.loc[df_final['skill'].isin(list(row.skills)), ['coef']].mean().values[0]
    
    if(not np.isnan(coef_avg) and type(row.salary)==list):
        return int((row.salary[1]-row.salary[0]) * coef_avg + row.salary[0])
    else:
        return row.salary #je fais quoi quand c'est une fourchette?
       
    
    

df_data['prediction'] = df_data.apply(lambda ligne: predict_salary(ligne) , axis=1)

#ternary operator(if en une ligne)
#j'ajoute colonne moyenne de la fourchette salary
# et je calcule moyenne de salary si le type est une liste, sinon juste le salaire
df_data['avg_salaire'] = df_data.apply(lambda l: int((l.salary[1]+l.salary[0])/2 if type(l.salary)==list else l.salary) , axis=1)

df_data
# Out:
#                salary                                             skills  \
# 0               40000  {workflows, r, learning, statistique, shiny, p...
# 1      [30000, 40000]  {ux, r, numpy, learning, pandas, computing, fr...
# 2      [30000, 50000]  {r, learning, pandas, html, rnn, c, statistiqu...
# 3               40000  {r, workflows, learning, statistique, shiny, p...
# 4      [30000, 50000]  {r, learning, pandas, html, rnn, c, statistiqu...
# 5      [30000, 45000]                    {scrum, scripting, cloud, perl}
# 6               20160                                   {etl, c, sql, r}
# 7               44000                      {cloudera, ia, hadoop, spark}
# 8      [32000, 45000]  {scrum, cloud, learning, c, agile, javascript,...
# 9      [40000, 50000]  {node, autoscaling, cloud, react, aws, javascr...
# 10     [22000, 28000]                         {erp, html, c, agile, css}
# 11     [40000, 50000]       {arm, network, android, r, microej, mqtt, c}
# 12              30000                           {c, postgre, php, mysql}
# 13              35000     {poo, c, sgbd, php, mysql, agile, python, moe}
# 14              40000       {jquery, hibernate, mvc, js, agile, angular}
# 15     [35000, 50000]  {network, jira, android, r, microej, mqtt, amq...
# 16     [40000, 55000]  {android, r, microej, mqtt, javafx, git, amqp,...
# 17     [37000, 40000]  {javascript, angular, js, agile, framework, vu...
# 18     [33000, 38000]  {node, html, javascript, postgresql, react, fr...
# 19     [33000, 40000]                           {javascript, css, mysql}
# 20              27000  {jquery, html, javascript, boostrap, framework...
# 21     [34000, 40000]                              {scrum, scala, agile}
# 22     [35000, 45000]                      {kubernetes, devops, symfony}
# 23     [40000, 50000]                 {ux, html, crm, php, js, css, etl}
# 24     [35000, 45000]                    {javascript, c, angular, agile}
# 25     [35000, 45000]                      {react, selenium, cloud, php}
# 26     [35000, 43000]  {node, react, git, c, js, agile, javascript, c...
# 27     [35000, 43000]                  {react, c, js, agile, javascript}
# 28              40000       {jquery, hibernate, mvc, js, agile, angular}
# 29     [20000, 40000]  {html, cloud, javascript, angularjs, c, scrum,...
# ...               ...                                                ...
# 2082             8400  {drupal, debian, wordpress, aws, wget, symfony...
# 2083            50000  {node, android, react, flask, js, mongodb, pyt...
# 2084            14400  {nlp, kubernetes, learning, git, bash, js, fra...
# 2085   [38000, 42000]  {cloud, qemu, c, mysql, nodejs, framework, vm,...
# 2086   [40000, 45000]                                      {webdev, sql}
# 2087   [30000, 35000]  {scrum, jquery, html, responsive, drupal, xhtm...
# 2088            19200  {laravel, elasticsearch, php, mysql, framework...
# 2089            45000                         {r, c, ia, python, django}
# 2090            22800  {redux, html, jira, angular, sass, git, c, agi...
# 2091   [45000, 60000]  {jquery, react, weblogic, js, scrum, devops, o...
# 2092   [35000, 45000]    {qml, matlab, git, c, agile, framework, python}
# 2093   [30000, 50000]  {network, laravel, android, symfony, c, php, s...
# 2094            40000  {html, network, android, symfony, drupal, git,...
# 2095   [40000, 65000]  {qliksense, scripting, datastage, r, learning,...
# 2096            14400  {nlp, r, flask, chatbot, learning, analytics, ...
# 2097            12600                                   {pipedrive, crm}
# 2098            14400                 {powerpoint, datastudio, bigquery}
# 2099   [43000, 46000]                                       {powerpoint}
# 2100            63000                                           {erp, c}
# 2101  [90000, 100000]                                        {analytics}
# 2102            54000  {scrum, cloudera, ml, bdd, learning, scikit, s...
# 2103            13200  {etl, c, warehouse, scrum, python, postgresql,...
# 2104   [35000, 45000]                                  {erp, cloud, sap}
# 2105   [30000, 33000]                                         {sourcing}
# 2106   [40000, 45000]  {erp, lumira, shellscript, git, sql, vbscript,...
# 2107            12000                           {crm, c, datalake, btob}
# 2108   [40000, 60000]                                    {c, trading, r}
# 2109   [45000, 55000]                                  {erp, cloud, sap}
# 2110            96000                  {reportings, etl, scripting, sql}
# 2111            25200                                {german, motivated}
#
#      prediction  avg_salaire
# 0         40000        40000
# 1         36421        35000
# 2         42954        40000
# 3         40000        40000
# 4         42954        40000
# 5         41072        37500
# 6         20160        20160
# 7         44000        44000
# 8         43728        38500
# 9         48090        45000
# 10        26045        25000
# 11        46017        45000
# 12        30000        30000
# 13        35000        35000
# 14        40000        40000
# 15        43915        42500
# 16        49929        47500
# 17        39267        38500
# 18        36645        35500
# 19        38195        36500
# 20        27000        27000
# 21        39123        37000
# 22        41798        40000
# 23        46573        45000
# 24        44218        40000
# 25        42234        40000
# 26        41146        39000
# 27        41892        39000
# 28        40000        40000
# 29        33685        30000
# ...         ...          ...
# 2082       8400         8400
# 2083      50000        50000
# 2084      14400        14400
# 2085      40843        40000
# 2086      42954        42500
# 2087      33043        32500
# 2088      19200        19200
# 2089      45000        45000
# 2090      22800        22800
# 2091      56574        52500
# 2092      43392        40000
# 2093      40038        40000
# 2094      40000        40000
# 2095      57316        52500
# 2096      14400        14400
# 2097      12600        12600
# 2098      14400        14400
# 2099      44094        44500
# 2100      63000        63000
# 2101      97001        95000
# 2102      54000        54000
# 2103      13200        13200
# 2104      42222        40000
# 2105      31834        31500
# 2106      43507        42500
# 2107      12000        12000
# 2108      56520        50000
# 2109      52222        50000
# 2110      96000        96000
# 2111      25200        25200
#
# [2112 rows x 4 columns]
